# %%
#!pip install gensim
#!pip install plotly
# !ls
# Out:
# HP_corpus.txt
# HP1.csv
# HP2.csv
# HP3.csv
# word2vec.ipynb

# %%
import pandas as pd
hp_texts = []

data_hp1 = pd.read_csv("HP1.csv",sep=";", encoding="unicode_escape")
data_hp2 = pd.read_csv("HP2.csv",sep=";", encoding="unicode_escape")
data_hp3 = pd.read_csv("HP3.csv",sep=";", encoding="unicode_escape")

hp1 = data_hp1.Sentence
hp2 = data_hp2.Sentence
hp3 = data_hp3.SENTENCE

hp_texts = [hp1, hp2, hp3]

# %%
corpus = []

#If you are running low on memory do this part using data streaming
for book in hp_texts:
    for line in book:
        corpus.append(line.encode("utf-8"))

# %%
corpus[0:10]
# Out:
# [b"I should've known that you would be here, Professor McGonagall.",
#  b'Good evening, Professor Dumbledore.',
#  b'Are the rumors true, Albus?',
#  b"I'm afraid so, professor.",
#  b'The good and the bad.',
#  b'And the boy?',
#  b'Hagrid is bringing him.',
#  b'Do you think it wise to trust Hagrid with something as important as this?',
#  b'Ah, Professor, I would trust Hagrid with my life.',
#  b'Professor Dumbledore, sir.']

# %%
with open('HP_corpus.txt', 'w') as filehandle:
    filehandle.writelines("%s\n" % line for line in corpus)

# %%
from gensim.test.utils import datapath
from gensim import utils

class MyCorpusMemory(object, ):
    """An interator that yields sentences (lists of str)."""

    def __iter__(self):
        corpus_path = datapath('HP_corpus.txt')
        for line in corpus:
            # assume there's one document per line, tokens separated by whitespace
            yield utils.simple_preprocess(line)

# %%
import gensim.models

sentences = MyCorpusMemory()
model = gensim.models.Word2Vec(sentences=sentences, size=200)

# %%
from sklearn.decomposition import IncrementalPCA    # inital reduction
from sklearn.manifold import TSNE                   # final reduction
import numpy as np                                  # array handling


def reduce_dimensions(model):
    num_dimensions = 2  # final num dimensions (2D, 3D, etc)

    vectors = [] # positions in vector space
    labels = [] # keep track of words to label our data again later
    for word in model.wv.vocab:
        vectors.append(model.wv[word])
        labels.append(word)

    # convert both lists into numpy vectors for reduction
    vectors = np.asarray(vectors)
    labels = np.asarray(labels)

    # reduce using t-SNE
    vectors = np.asarray(vectors)
    tsne = TSNE(n_components=num_dimensions, random_state=0)
    vectors = tsne.fit_transform(vectors)

    x_vals = [v[0] for v in vectors]
    y_vals = [v[1] for v in vectors]
    return x_vals, y_vals, labels


x_vals, y_vals, labels = reduce_dimensions(model)

def plot_with_plotly(x_vals, y_vals, labels, plot_in_notebook=True):
    from plotly.offline import init_notebook_mode, iplot, plot
    import plotly.graph_objs as go

    trace = go.Scatter(x=x_vals, y=y_vals, mode='text', text=labels)
    data = [trace]

    if plot_in_notebook:
        init_notebook_mode(connected=True)
        iplot(data, filename='word-embedding-plot')
    else:
        plot(data, filename='word-embedding-plot.html')


def plot_with_matplotlib(x_vals, y_vals, labels):
    import matplotlib.pyplot as plt
    import random

    random.seed(0)

    plt.figure(figsize=(12, 12))
    plt.scatter(x_vals, y_vals)

    #
    # Label randomly subsampled 25 data points
    #
    indices = list(range(len(labels)))
    selected_indices = random.sample(indices, 25)
    for i in selected_indices:
        plt.annotate(labels[i], (x_vals[i], y_vals[i]))

try:
    get_ipython()
except Exception:
    plot_function = plot_with_matplotlib
else:
    plot_function = plot_with_plotly

plot_function(x_vals, y_vals, labels)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="62ac10a1-1494-404b-9529-02b22ed21706" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("62ac10a1-1494-404b-9529-02b22ed21706")) {                    Plotly.newPlot(                        "62ac10a1-1494-404b-9529-02b22ed21706",                        [{"mode": "text", "text": ["should", "ve", "known", "that", "you", "would", "be", "here", "professor", "mcgonagall", "good", "evening", "dumbledore", "are", "the", "true", "albus", "afraid", "so", "and", "bad", "boy", "hagrid", "is", "him", "do", "think", "it", "to", "trust", "with", "something", "as", "important", "this", "ah", "my", "life", "sir", "no", "little", "fell", "just", "we", "were", "flying", "over", "try", "not", "wake", "there", "go", "really", "safe", "leaving", "these", "people", "them", "all", "day", "they", "re", "worst", "sort", "of", "muggles", "only", "family", "he", "has", "will", "famous", "won", "in", "our", "world", "who", "doesn", "know", "his", "name", "exactly", "far", "better", "off", "up", "away", "from", "until", "ready", "goodbye", "after", "luck", "harry", "potter", "get", "now", "going", "comes", "birthday", "happy", "why", "don", "anything", "yes", "petunia", "want", "everything", "for", "dudley", "hurry", "bring", "uncle", "vernon", "aren", "wonderful", "how", "many", "myself", "but", "last", "year", "had", "some", "quite", "bit", "than", "care", "big", "oh", "what", "when", "out", "two", "new", "at", "looking", "any", "funny", "business", "have", "week", "make", "move", "sorry", "about", "understand", "like", "their", "on", "can", "hear", "me", "never", "snake", "before", "mean", "talk", "was", "nice", "miss", "your", "see", "well", "knew", "parents", "either", "mummy", "dad", "come", "believe", "doing", "thanks", "mum", "help", "did", "right", "ll", "clothes", "happened", "swear", "one", "minute", "then", "gone", "magic", "such", "thing", "look", "moment", "too", "state", "school", "where", "old", "fit", "enough", "post", "marge", "got", "hey", "give", "back", "yours", "more", "mail", "through", "office", "dear", "fine", "best", "because", "today", "bloody", "stop", "let", "find", "us", "mad", "wish", "leave", "once", "great", "mind", "haven", "seen", "since", "along", "round", "am", "course", "might", "imagine", "same", "words", "thank", "every", "young", "man", "turns", "excuse", "grounds", "hogwarts", "blimey", "didn", "ever", "wonder", "wizard", "made", "happen", "couldn", "or", "scared", "mr", "been", "wizardry", "took", "put", "rubbish", "told", "could", "being", "she", "mother", "father", "proud", "her", "witch", "isn", "met", "strange", "if", "please", "went", "died", "car", "killed", "lily", "james", "say", "an", "suppose", "muggle", "yourself", "down", "born", "headmaster", "pay", "fool", "teach", "front", "um", "tell", "anyone", "allowed", "okay", "ooh", "behind", "unless", "rather", "stay", "first", "students", "three", "work", "wand", "dragon", "real", "must", "cauldron", "may", "owl", "cat", "tom", "bless", "soul", "welcome", "meet", "hello", "quirrell", "defense", "against", "dark", "arts", "teacher", "need", "those", "sure", "person", "alley", "class", "broom", "place", "except", "perhaps", "things", "clever", "most", "close", "does", "wait", "ha", "devil", "else", "gave", "vault", "which", "very", "nothing", "secret", "stand", "mention", "still", "run", "long", "seeing", "seems", "matter", "curious", "remember", "happens", "another", "other", "its", "brother", "scar", "speak", "always", "clear", "expect", "terrible", "seem", "quiet", "wizards", "few", "years", "ago", "maybe", "spell", "voldemort", "times", "brought", "side", "dead", "decided", "kill", "tried", "mark", "by", "curse", "absolutely", "certain", "night", "knows", "time", "gonna", "uh", "trai ...

# %%
vec_harry = model.wv['harry']

# %%
import matplotlib.pyplot as plt

plt.plot(vec_harry)
